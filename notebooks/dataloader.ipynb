# %%
# %cd ..
# Out:
# /home/sven/Developer/git/Pose-Estimation-TF2

# %%
from pose_estimation.config import cfg
import numpy as np
import matplotlib.pylab as plt
from pose_estimation.data_utils.dataset import get_dataloaders

# %%
ds = get_dataloaders(4, 2, 2)
batch = next(iter(ds))
# Out:
# loading annotations into memory...
# Done (t=4.75s)
# creating index...
# index created!

# %%
input_imgs = batch[0].numpy()
heatmaps = batch[1].numpy()

# %%
for i in range(input_imgs.shape[0]):
    img = cfg.denormalize_input(input_imgs[i])[:, :, ::-1].astype(np.uint8)
    heatmap = heatmaps[i].sum(-1)
    plt.imshow(heatmap)
    plt.show()
    plt.imshow(img)
    plt.show()
